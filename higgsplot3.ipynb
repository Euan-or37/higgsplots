# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_2e2mu = pd.read_csv("2e2mu_2012.csv")
df_4e = pd.read_csv("4e_2012.csv")
df_4mu = pd.read_csv("4mu_2012.csv")

df_all = pd.concat([df_2e2mu, df_4e, df_4mu], ignore_index=True)

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_all["M"], bins=30, range=(70, 180), color='skyblue', edgecolor='black')
plt.axvline(125, color='red', linestyle='--', label='Higgs ~125 GeV')
plt.title("Combined 4-Lepton Invariant Mass (2012 Data)")
plt.xlabel("Invariant Mass [GeV]")
plt.ylabel("Number of Events")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
in_peak = df_all[(df_all["M"] > 120) & (df_all["M"] < 130)]
print(f"Number of events between 120–130 GeV: {len(in_peak)}")
# Out:
# Number of events between 120–130 GeV: 11

# %%
total = df_all[(df_all["M"] > 80) & (df_all["M"] < 180)]
print(f"Number of events between 80–180 GeV: {len(total)}")
# Out:
# Number of events between 80–180 GeV: 79
